# %%
# reading in articles.B2M.csv
import pandas as pd
from pathlib import Path

# adjust the path based on your actual file location
articles = pd.read_csv('articles.B2M.csv')  # Try without Group_2 folders

articles.head()
# Out:
#        PMID                                              Title  \
# 0  10575721  [Computer-assisted preoperative planning of kn...
# 1  10617805  [Urogenital amyloidosis: clinico-pathological ...
# 2  10656443  Serum beta-2 microglobulin levels are a signif...
# 3  10790290  Exposure of Daudi cells to low-frequency magne...
# 4  10793017  Effects of dialyzer reuse on the permeability ...
#
#                                             Abstract       ISSN  \
# 0  The general configuration of replaced knee is ...  0035-1040
# 1  Amyloidosis of the genito-urinary tract is unc...  0242-6498
# 2  Our objective was to investigate the prognosti...  1078-0432
# 3  The effect of extremely low-frequency electrom...  0033-7587
# 4  Little attention has been given to the effects...  1523-6838
#
#                                              Journal      Location  Year  \
# 0  Revue de chirurgie orthopedique et reparatrice...  (85) 591-600  1999
# ...

# %%
# creating a new dataframe with only articles from 2022-2024

new_articles = articles[articles['Year'].isin([2022, 2023, 2024])]

new_articles.head()
# Out:
#          PMID                                              Title  \
# 512  33945142  CRISPR/Cas9 Ribonucleoprotein Complex-Mediated...
# 518  34182799  Generation of Monkey Induced Pluripotent Stem ...
# 526  34305082  Beta-2-Microglobulin is an Independent Risk Fa...
# 537  34560683  A Comprehensive Clinicopathologic and Molecula...
# 538  34613461  Histo-molecular characterization of pancreatic...
#
#                                               Abstract       ISSN  \
# 512  Advances in induced pluripotent stem cell (iPS...  1940-6029
# 518  Due to the poor capacity for articular cartila...  1937-335X
# 526  To identify the association between serum beta...  1880-3873
# 537  Primary effusion lymphoma (PEL) is associated ...  1532-0979
# 538  Pancreatic ductal adenocarcinoma (PDAC) with m...  1432-2307
#
#                                                Journal         Location  Year  \
# 512       Methods in molecular biology (Clifton, N.J.)   (2454) 607-624  2022
# ...
